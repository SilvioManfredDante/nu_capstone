# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import zipfile

# %%
path='../data/raw/earnings_call_transcripts.csv.zip'

reg_path = 'earnings_call_transcripts.csv'

# %%
with zipfile.ZipFile(path, 'r') as z:
    with z.open(reg_path) as f:
        df = pd.read_csv(f)

# %%
df
# Out:
#     ticker quarter            date_time  \
# 0     NVDA      Q1  2024-05-24 17:00:00
# 1     NVDA      Q2  2024-08-23 17:00:00
# 2     NVDA      Q3  2024-11-21 17:00:00
# 3     NVDA      Q4  2024-02-21 17:00:00
# 4     NVDA      Q1  2023-05-25 12:00:00
# ..     ...     ...                  ...
# 723   LRCX      Q3  2021-04-21 17:00:00
# 724   LRCX      Q4  2021-07-28 17:00:00
# 725   LRCX      Q1  2020-10-23 17:00:00
# 726   LRCX      Q2  2020-01-29 17:57:00
# 727   LRCX      Q3  2020-04-23 17:00:00
#
#                                          speakers_list  \
# 0    ['Tim Arcuri', 'Colette Kress', 'Toshiya Hari'...
# 1    ['Colette Kress', 'Operator', 'Stacy Rasgon', ...
# 2    ['Tim Arcuri', 'Colette Kress', 'Operator', 'T...
# 3    ['Colette Kress', 'Toshiya Hari', 'Operator', ...
# 4    ['Chris Caso', 'Tim Arcuri', 'Colette Kress', ...
# ..                                                 ...
# 723                                                NaN
# 724                                                NaN
# 725                                                NaN
# 726                                                NaN
# 727                                                NaN
#
#                                             transcript
# 0    Operator: Good afternoon. My name is David, an...
# 1    Operator: Good afternoon. My name is David, an...
# 2    Operator: Good afternoon. My name is JL, and I...
# 3    Operator: Good afternoon. My name is Rob and I...
# 4    Operator: Good afternoon. My name is David, an...
# ..                                                 ...
# 723  Operator: Good day, and welcome to Lam Researc...
# 724  Operator: Good day, and welcome to the June 20...
# 725  Operator: Good day, and welcome to the Septemb...
# 726  Operator: Good day, and welcome to the Lam Res...
# 727  Operator: Good day, and welcome to the Lam Res...
#
# [728 rows x 5 columns]
