# %%
# %pip install llama-index-readers-earnings-call-transcript
# %pip install llama-index-embeddings-openai
# %pip install -r /Users/LVal18/Documents/GitHub/nu_capstone/requirements.txt
# Out:
# Requirement already satisfied: llama-index-readers-earnings-call-transcript in /usr/local/lib/python3.11/site-packages (0.3.0)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /usr/local/lib/python3.11/site-packages (from llama-index-readers-earnings-call-transcript) (0.12.11)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.11/site-packages (from llama-index-readers-earnings-call-transcript) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in /usr/local/lib/python3.11/site-packages (from llama-index-readers-earnings-call-transcript) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (3.11.11)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (2024.12.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/LVal18/Library/Python/3.11/lib/python/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (2.10.5)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/LVal18/Library/Python/3.11/lib/python/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (1.17.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests<3.0.0,>=2.31.0->llama-index-readers-earnings-call-transcript) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests<3.0.0,>=2.31.0->llama-index-readers-earnings-call-transcript) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests<3.0.0,>=2.31.0->llama-index-readers-earnings-call-transcript) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests<3.0.0,>=2.31.0->llama-index-readers-earnings-call-transcript) (2024.12.14)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (1.18.3)
# Requirement already satisfied: click in /usr/local/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (2.27.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (3.25.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in /Users/LVal18/Library/Python/3.11/lib/python/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (24.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-earnings-call-transcript) (1.3.1)
#
# [notice] A new release of pip is available: 24.2 -> 25.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-index-embeddings-openai in /usr/local/lib/python3.11/site-packages (0.3.1)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /usr/local/lib/python3.11/site-packages (from llama-index-embeddings-openai) (0.12.11)
# Requirement already satisfied: openai>=1.1.0 in /usr/local/lib/python3.11/site-packages (from llama-index-embeddings-openai) (1.59.7)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.11.11)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2024.12.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/LVal18/Library/Python/3.11/lib/python/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.10.5)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/LVal18/Library/Python/3.11/lib/python/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.17.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/site-packages (from openai>=1.1.0->llama-index-embeddings-openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/site-packages (from openai>=1.1.0->llama-index-embeddings-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/site-packages (from openai>=1.1.0->llama-index-embeddings-openai) (0.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/site-packages (from openai>=1.1.0->llama-index-embeddings-openai) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.18.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-embeddings-openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.14.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.25.1)
# Requirement already satisfied: packaging>=17.0 in /Users/LVal18/Library/Python/3.11/lib/python/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (24.2)
#
# [notice] A new release of pip is available: 24.2 -> 25.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
#
# [notice] A new release of pip is available: 24.2 -> 25.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import re
from datetime import datetime
from typing import List
import requests
from tenacity import retry, stop_after_attempt, wait_random_exponential
from llama_index.core.readers.base import BaseReader
from llama_index.core.schema import Document

# Set key
dcf_key = "0fd07d8c-a42a-4735-9aea-2c8db692830e"

def correct_date(yr, dt):
    """Some transcripts have incorrect date, correcting it.

    Args:
        yr (int): actual
        dt (datetime): given date

    Returns:
        datetime: corrected date
    """
    dt = datetime.strptime(dt, "%Y-%m-%d %H:%M:%S")
    if dt.year != yr:
        dt = dt.replace(year=yr)
    return dt.strftime("%Y-%m-%d %H:%M:%S")


def extract_speakers(cont: str) -> List[str]:
    """Extract the list of speakers.

    Args:
        cont (str): transcript content

    Returns:
        List[str]: list of speakers
    """
    pattern = re.compile(r"\n(.*?):")
    matches = pattern.findall(cont)

    return list(set(matches))


@retry(wait=wait_random_exponential(min=1, max=5), stop=stop_after_attempt(2))
def get_earnings_transcript(quarter: str, ticker: str, year: int):
    """Get the earnings transcripts.

    Args:
        quarter (str)
        ticker (str)
        year (int)
    """
    response = requests.get(
        # f"https://discountingcashflows.com/api/transcript/{ticker}/{quarter}/{year}/",
        f"https://discountingcashflows.com/api/transcript/?ticker={ticker}&quarter={quarter}&year={year}&key={dcf_key}",
        auth=("user", "pass"),
    )

    resp_text = json.loads(response.text)
    speakers_list = extract_speakers(resp_text[0]["content"])
    corrected_date = correct_date(resp_text[0]["year"], resp_text[0]["date"])
    resp_text[0]["date"] = corrected_date
    return resp_text[0], speakers_list

class EarningsCallTranscriptDCF(BaseReader):
    def __init__(self, year: int, ticker: str, quarter: str):
        """Get the earning call transcripts for a given company, in a given year and quarter.

        Args:
            year (int): Year of the transcript
            ticker (str): ticker symbol of the stock
            quarter (str): quarter
        """
        curr_year = datetime.now().year
        assert year <= curr_year, "The year should be less than current year"

        assert quarter in [
            "Q1",
            "Q2",
            "Q3",
            "Q4",
        ], 'The quarter should from the list ["Q1","Q2","Q3","Q4"]'
        self.year = year
        self.ticker = ticker
        self.quarter = quarter

    def load_data(self) -> List[Document]:
        resp_dict, speakers_list = get_earnings_transcript(
            self.quarter, self.ticker, self.year
        )
        return Document(
            text=resp_dict["content"],
            extra_info={
                "ticker": resp_dict["symbol"],
                "quarter": "Q" + str(resp_dict["quarter"]),
                "date_time": resp_dict["date"],
                "speakers_list": speakers_list,
            },
        )

# %%
import csv
import pandas as pd
import requests
from datetime import datetime
from llama_index.readers.earnings_call_transcript import EarningsCallTranscript
import os



# Define last n years dynamically
n_years = 10
current_year = datetime.now().year
years_list = [current_year - i - 1 for i in range(n_years)]
quarters = ["Q1", "Q2", "Q3", "Q4"]  # Standardized quarter format

# Load stock list
stock_list = pd.read_csv("/Users/LVal18/Documents/GitHub/nu_capstone/data/processed/sp50_tech_stocks.csv")
companies = stock_list["Symbol"].tolist()

# Define CSV file path
csv_file_path = "earnings_call_transcripts.csv"

# Define API endpoint for checking individual tickers
DCF_API_URL_TEMPLATE = "https://discountingcashflows.com/api/profile/?ticker={ticker}&key={dcf_key}"

# Function to check if a ticker is available in DCF API
def is_ticker_available(ticker):
    try:
        response = requests.get(DCF_API_URL_TEMPLATE.format(ticker=ticker,dcf_key=dcf_key))
        return response.status_code == 200  # If the API returns 200, the ticker exists
    except requests.RequestException as e:
        print(f"❌ API request failed for {ticker}: {e}")
        return False  # Treat failed requests as unavailable tickers

# Load existing processed records (ticker, year, quarter) from the CSV
existing_records = set()
if os.path.exists(csv_file_path):
    with open(csv_file_path, mode="r", newline="", encoding="utf-8") as file:
        reader = csv.DictReader(file)
        for row in reader:
            existing_records.add((row["ticker"], row["date_time"][:4], row["quarter"]))  # Store as (ticker, year, quarter)

# Open CSV file and append new data
with open(csv_file_path, mode="a", newline="", encoding="utf-8") as file:
    fieldnames = ["ticker", "quarter", "date_time", "speakers_list", "transcript"]
    writer = csv.DictWriter(file, fieldnames=fieldnames)

    # If file was empty, write the header
    if os.stat(csv_file_path).st_size == 0:
        writer.writeheader()

    # Fetch earnings call transcripts
    for ticker in companies:
        if not is_ticker_available(ticker):  # Check ticker availability first
            print(f"⚠️ Skipping {ticker}: Not found in DCF API.")
            continue  # Skip unavailable tickers

        try:
            for year in years_list:
                for quarter in quarters:
                    if (ticker, str(year), quarter) in existing_records:
                        print(f"⏭️ Skipping {ticker} {year} {quarter}: Already in CSV.")
                        continue  # Skip already processed records

                    loader = EarningsCallTranscriptDCF(year, ticker, quarter)
                    doc = loader.load_data()
                    row_data = {
                        "ticker": ticker,
                        "quarter": quarter,
                        "date_time": doc.metadata.get("date_time", "N/A"),
                        "speakers_list": ", ".join(doc.metadata.get("speakers", [])),
                        "transcript": doc.text  # Limit transcript size
                    }
                    writer.writerow(row_data)

                    print(f"✅ Successfully fetched data for {ticker} in {year} {quarter}")

        except Exception as e:
            print(f"❌ Error fetching data for {ticker}. Skipping to next ticker. Error: {e}")
            continue  # Move to the next ticker

print(f"\n✅ Data saved to {csv_file_path}")
# Out:
# ⏭️ Skipping NVDA 2024 Q1: Already in CSV.
# ⏭️ Skipping NVDA 2024 Q2: Already in CSV.
# ⏭️ Skipping NVDA 2024 Q3: Already in CSV.
# ⏭️ Skipping NVDA 2024 Q4: Already in CSV.
# ⏭️ Skipping NVDA 2023 Q1: Already in CSV.
# ⏭️ Skipping NVDA 2023 Q2: Already in CSV.
# ⏭️ Skipping NVDA 2023 Q3: Already in CSV.
# ⏭️ Skipping NVDA 2023 Q4: Already in CSV.
# ⏭️ Skipping NVDA 2022 Q1: Already in CSV.
# ⏭️ Skipping NVDA 2022 Q2: Already in CSV.
# ⏭️ Skipping NVDA 2022 Q3: Already in CSV.
# ⏭️ Skipping NVDA 2022 Q4: Already in CSV.
# ⏭️ Skipping NVDA 2021 Q1: Already in CSV.
# ⏭️ Skipping NVDA 2021 Q2: Already in CSV.
# ⏭️ Skipping NVDA 2021 Q3: Already in CSV.
# ⏭️ Skipping NVDA 2021 Q4: Already in CSV.
# ⏭️ Skipping NVDA 2020 Q1: Already in CSV.
# ⏭️ Skipping NVDA 2020 Q2: Already in CSV.
# ⏭️ Skipping NVDA 2020 Q3: Already in CSV.
# ⏭️ Skipping NVDA 2020 Q4: Already in CSV.
# ⏭️ Skipping NVDA 2019 Q1: Already in CSV.
# ⏭️ Skipping NVDA 2019 Q2: Already in CSV.
# ⏭️ Skipping NVDA 2019 Q3: Already in CSV.
# ⏭️ Skipping NVDA 2019 Q4: Already in CSV.
# ⏭️ Skipping NVDA 2018 Q1: Already in CSV.
# ⏭️ Skipping NVDA 2018 Q2: Already in CSV.
# ⏭️ Skipping NVDA 2018 Q3: Already in CSV.
# ⏭️ Skipping NVDA 2018 Q4: Already in CSV.
# ⏭️ Skipping NVDA 2017 Q1: Already in CSV.
# ⏭️ Skipping NVDA 2017 Q2: Already in CSV.
# ⏭️ Skipping NVDA 2017 Q3: Already in CSV.
# ⏭️ Skipping NVDA 2017 Q4: Already in CSV.
# ⏭️ Skipping NVDA 2016 Q1: Already in CSV.
# ⏭️ Skipping NVDA 2016 Q2: Already in CSV.
# ⏭️ Skipping NVDA 2016 Q3: Already in CSV.
# ⏭️ Skipping NVDA 2016 Q4: Already in CSV.
# ⏭️ Skipping NVDA 2015 Q1: Already in CSV.
# ⏭️ Skipping NVDA 2015 Q2: Already in CSV.
# ⏭️ Skipping NVDA 2015 Q3: Already in CSV.
# ⏭️ Skipping NVDA 2015 Q4: Already in CSV.
# ⏭️ Skipping AAPL 2024 Q1: Already in CSV.
# ⏭️ Skipping AAPL 2024 Q2: Already in CSV.
# ⏭️ Skipping AAPL 2024 Q3: Already in CSV.
# ⏭️ Skipping AAPL 2024 Q4: Already in CSV.
# ⏭️ Skipping AAPL 2023 Q1: Already in CSV.
# ⏭️ Skipping AAPL 2023 Q2: Already in CSV.
# ⏭️ Skipping AAPL 2023 Q3: Already in CSV.
# ⏭️ Skipping AAPL 2023 Q4: Already in CSV.
# ⏭️ Skipping AAPL 2022 Q1: Already in CSV.
# ⏭️ Skipping AAPL 2022 Q2: Already in CSV.
# ⏭️ Skipping AAPL 2022 Q3: Already in CSV.
# ⏭️ Skipping AAPL 2022 Q4: Already in CSV.
# ⏭️ Skipping AAPL 2021 Q1: Already in CSV.
# ⏭️ Skipping AAPL 2021 Q2: Already in CSV.
# ⏭️ Skipping AAPL 2021 Q3: Already in CSV.
# ⏭️ Skipping AAPL 2021 Q4: Already in CSV.
# ⏭️ Skipping AAPL 2020 Q1: Already in CSV.
# ⏭️ Skipping AAPL 2020 Q2: Already in CSV.
# ⏭️ Skipping AAPL 2020 Q3: Already in CSV.
# ⏭️ Skipping AAPL 2020 Q4: Already in CSV.
# ⏭️ Skipping AAPL 2019 Q1: Already in CSV.
# ⏭️ Skipping AAPL 2019 Q2: Already in CSV.
# ⏭️ Skipping AAPL 2019 Q3: Already in CSV.
# ⏭️ Skipping AAPL 2019 Q4: Already in CSV.
# ⏭️ Skipping AAPL 2018 Q1: Already in CSV.
# ⏭️ Skipping AAPL 2018 Q2: Already in CSV.
# ⏭️ Skipping AAPL 2018 Q3: Already in CSV.
# ⏭️ Skipping AAPL 2018 Q4: Already in CSV.
# ⏭️ Skipping AAPL 2017 Q1: Already in CSV.
# ⏭️ Skipping AAPL 2017 Q2: Already in CSV.
# ⏭️ Skipping AAPL 2017 Q3: Already in CSV.
# ⏭️ Skipping AAPL 2017 Q4: Already in CSV.
# ⏭️ Skipping AAPL 2016 Q1: Already in CSV.
# ⏭️ Skipping AAPL 2016 Q2: Already in CSV.
# ⏭️ Skipping AAPL 2016 Q3: Already in CSV.
# ⏭️ Skipping AAPL 2016 Q4: Already in CSV.
# ⏭️ Skipping AAPL 2015 Q1: Already in CSV.
# ⏭️ Skipping AAPL 2015 Q2: Already in CSV.
# ⏭️ Skipping AAPL 2015 Q3: Already in CSV.
# ⏭️ Skipping AAPL 2015 Q4: Already in CSV.
# ⏭️ Skipping MSFT 2024 Q1: Already in CSV.
# ⏭️ Skipping MSFT 2024 Q2: Already in CSV.
# ⏭️ Skipping MSFT 2024 Q3: Already in CSV.
# ⏭️ Skipping MSFT 2024 Q4: Already in CSV.
# ⏭️ Skipping MSFT 2023 Q1: Already in CSV.
# ⏭️ Skipping MSFT 2023 Q2: Already in CSV.
# ⏭️ Skipping MSFT 2023 Q3: Already in CSV.
# ⏭️ Skipping MSFT 2023 Q4: Already in CSV.
# ⏭️ Skipping MSFT 2022 Q1: Already in CSV.
# ⏭️ Skipping MSFT 2022 Q2: Already in CSV.
# ⏭️ Skipping MSFT 2022 Q3: Already in CSV.
# ⏭️ Skipping MSFT 2022 Q4: Already in CSV.
# ⏭️ Skipping MSFT 2021 Q1: Already in CSV.
# ⏭️ Skipping MSFT 2021 Q2: Already in CSV.
# ⏭️ Skipping MSFT 2021 Q3: Already in CSV.
# ⏭️ Skipping MSFT 2021 Q4: Already in CSV.
# ⏭️ Skipping MSFT 2020 Q1: Already in CSV.
# ⏭️ Skipping MSFT 2020 Q2: Already in CSV.
# ⏭️ Skipping MSFT 2020 Q3: Already in CSV.
# ⏭️ Skipping MSFT 2020 Q4: Already in CSV.
# ⏭️ Skipping MSFT 2019 Q1: Already in CSV.
# ⏭️ Skipping MSFT 2019 Q2: Already in CSV.
# ⏭️ Skipping MSFT 2019 Q3: Already in CSV.
# ⏭️ Skipping MSFT 2019 Q4: Already in CSV.
# ⏭️ Skipping MSFT 2018 Q1: Already in CSV.
# ⏭️ Skipping MSFT 2018 Q2: Already in CSV.
# ⏭️ Skipping MSFT 2018 Q3: Already in CSV.
# ⏭️ Skipping MSFT 2018 Q4: Already in CSV.
# ⏭️ Skipping MSFT 2017 Q1: Already in CSV.
# ⏭️ Skipping MSFT 2017 Q2: Already in CSV.
# ⏭️ Skipping MSFT 2017 Q3: Already in CSV.
# ⏭️ Skipping MSFT 2017 Q4: Already in CSV.
# ⏭️ Skipping MSFT 2016 Q1: Already in CSV.
# ⏭️ Skipping MSFT 2016 Q2: Already in CSV.
# ⏭️ Skipping MSFT 2016 Q3: Already in CSV.
# ⏭️ Skipping MSFT 2016 Q4: Already in CSV.
# ⏭️ Skipping MSFT 2015 Q1: Already in CSV.
# ⏭️ Skipping MSFT 2015 Q2: Already in CSV.
# ⏭️ Skipping MSFT 2015 Q3: Already in CSV.
# ⏭️ Skipping MSFT 2015 Q4: Already in CSV.
# ⏭️ Skipping AVGO 2024 Q1: Already in CSV.
# ⏭️ Skipping AVGO 2024 Q2: Already in CSV.
# ⏭️ Skipping AVGO 2024 Q3: Already in CSV.
# ⏭️ Skipping AVGO 2024 Q4: Already in CSV.
# ⏭️ Skipping AVGO 2023 Q1: Already in CSV.
# ⏭️ Skipping AVGO 2023 Q2: Already in CSV.
# ⏭️ Skipping AVGO 2023 Q3: Already in CSV.
# ⏭️ Skipping AVGO 2023 Q4: Already in CSV.
# ⏭️ Skipping AVGO 2022 Q1: Already in CSV.
# ⏭️ Skipping AVGO 2022 Q2: Already in CSV.
# ⏭️ Skipping AVGO 2022 Q3: Already in CSV.
# ⏭️ Skipping AVGO 2022 Q4: Already in CSV.
# ⏭️ Skipping AVGO 2021 Q1: Already in CSV.
# ⏭️ Skipping AVGO 2021 Q2: Already in CSV.
# ⏭️ Skipping AVGO 2021 Q3: Already in CSV.
# ⏭️ Skipping AVGO 2021 Q4: Already in CSV.
# ⏭️ Skipping AVGO 2020 Q1: Already in CSV.
# ⏭️ Skipping AVGO 2020 Q2: Already in CSV.
# ⏭️ Skipping AVGO 2020 Q3: Already in CSV.
# ⏭️ Skipping AVGO 2020 Q4: Already in CSV.
# ⏭️ Skipping AVGO 2019 Q1: Already in CSV.
# ⏭️ Skipping AVGO 2019 Q2: Already in CSV.
# ⏭️ Skipping AVGO 2019 Q3: Already in CSV.
# ⏭️ Skipping AVGO 2019 Q4: Already in CSV.
# ⏭️ Skipping AVGO 2018 Q1: Already in CSV.
# ⏭️ Skipping AVGO 2018 Q2: Already in CSV.
# ⏭️ Skipping AVGO 2018 Q3: Already in CSV.
# ⏭️ Skipping AVGO 2018 Q4: Already in CSV.
# ⏭️ Skipping AVGO 2017 Q1: Already in CSV.
# ⏭️ Skipping AVGO 2017 Q2: Already in CSV.
# ⏭️ Skipping AVGO 2017 Q3: Already in CSV.
# ⏭️ Skipping AVGO 2017 Q4: Already in CSV.
# ⏭️ Skipping AVGO 2016 Q1: Already in CSV.
# ⏭️ Skipping AVGO 2016 Q2: Already in CSV.
# ⏭️ Skipping AVGO 2016 Q3: Already in CSV.
# ⏭️ Skipping AVGO 2016 Q4: Already in CSV.
# ⏭️ Skipping AVGO 2015 Q1: Already in CSV.
# ⏭️ Skipping AVGO 2015 Q2: Already in CSV.
# ⏭️ Skipping AVGO 2015 Q3: Already in CSV.
# ⏭️ Skipping AVGO 2015 Q4: Already in CSV.
# ⏭️ Skipping CRM 2024 Q1: Already in CSV.
# ⏭️ Skipping CRM 2024 Q2: Already in CSV.
# ⏭️ Skipping CRM 2024 Q3: Already in CSV.
# ⏭️ Skipping CRM 2024 Q4: Already in CSV.
# ⏭️ Skipping CRM 2023 Q1: Already in CSV.
# ⏭️ Skipping CRM 2023 Q2: Already in CSV.
# ⏭️ Skipping CRM 2023 Q3: Already in CSV.
# ⏭️ Skipping CRM 2023 Q4: Already in CSV.
# ⏭️ Skipping CRM 2022 Q1: Already in CSV.
# ⏭️ Skipping CRM 2022 Q2: Already in CSV.
# ⏭️ Skipping CRM 2022 Q3: Already in CSV.
# ⏭️ Skipping CRM 2022 Q4: Already in CSV.
# ⏭️ Skipping CRM 2021 Q1: Already in CSV.
# ⏭️ Skipping CRM 2021 Q2: Already in CSV.
# ⏭️ Skipping CRM 2021 Q3: Already in CSV.
# ⏭️ Skipping CRM 2021 Q4: Already in CSV.
# ⏭️ Skipping CRM 2020 Q1: Already in CSV.
# ⏭️ Skipping CRM 2020 Q2: Already in CSV.
# ⏭️ Skipping CRM 2020 Q3: Already in CSV.
# ⏭️ Skipping CRM 2020 Q4: Already in CSV.
# ⏭️ Skipping CRM 2019 Q1: Already in CSV.
# ⏭️ Skipping CRM 2019 Q2: Already in CSV.
# ⏭️ Skipping CRM 2019 Q3: Already in CSV.
# ⏭️ Skipping CRM 2019 Q4: Already in CSV.
# ⏭️ Skipping CRM 2018 Q1: Already in CSV.
# ⏭️ Skipping CRM 2018 Q2: Already in CSV.
# ⏭️ Skipping CRM 2018 Q3: Already in CSV.
# ⏭️ Skipping CRM 2018 Q4: Already in CSV.
# ⏭️ Skipping CRM 2017 Q1: Already in CSV.
# ⏭️ Skipping CRM 2017 Q2: Already in CSV.
# ⏭️ Skipping CRM 2017 Q3: Already in CSV.
# ⏭️ Skipping CRM 2017 Q4: Already in CSV.
# ⏭️ Skipping CRM 2016 Q1: Already in CSV.
# ⏭️ Skipping CRM 2016 Q2: Already in CSV.
# ⏭️ Skipping CRM 2016 Q3: Already in CSV.
# ⏭️ Skipping CRM 2016 Q4: Already in CSV.
# ⏭️ Skipping CRM 2015 Q1: Already in CSV.
# ⏭️ Skipping CRM 2015 Q2: Already in CSV.
# ⏭️ Skipping CRM 2015 Q3: Already in CSV.
# ⏭️ Skipping CRM 2015 Q4: Already in CSV.
# ⏭️ Skipping ORCL 2024 Q1: Already in CSV.
# ⏭️ Skipping ORCL 2024 Q2: Already in CSV.
# ⏭️ Skipping ORCL 2024 Q3: Already in CSV.
# ⏭️ Skipping ORCL 2024 Q4: Already in CSV.
# ⏭️ Skipping ORCL 2023 Q1: Already in CSV.
# ⏭️ Skipping ORCL 2023 Q2: Already in CSV.
# ⏭️ Skipping ORCL 2023 Q3: Already in CSV.
# ⏭️ Skipping ORCL 2023 Q4: Already in CSV.
# ⏭️ Skipping ORCL 2022 Q1: Already in CSV.
# ⏭️ Skipping ORCL 2022 Q2: Already in CSV.
# ⏭️ Skipping ORCL 2022 Q3: Already in CSV.
# ⏭️ Skipping ORCL 2022 Q4: Already in CSV.
# ⏭️ Skipping ORCL 2021 Q1: Already in CSV.
# ⏭️ Skipping ORCL 2021 Q2: Already in CSV.
# ⏭️ Skipping ORCL 2021 Q3: Already in CSV.
# ⏭️ Skipping ORCL 2021 Q4: Already in CSV.
# ⏭️ Skipping ORCL 2020 Q1: Already in CSV.
# ⏭️ Skipping ORCL 2020 Q2: Already in CSV.
# ⏭️ Skipping ORCL 2020 Q3: Already in CSV.
# ⏭️ Skipping ORCL 2020 Q4: Already in CSV.
# ⏭️ Skipping ORCL 2019 Q1: Already in CSV.
# ⏭️ Skipping ORCL 2019 Q2: Already in CSV.
# ⏭️ Skipping ORCL 2019 Q3: Already in CSV.
# ⏭️ Skipping ORCL 2019 Q4: Already in CSV.
# ⏭️ Skipping ORCL 2018 Q1: Already in CSV.
# ⏭️ Skipping ORCL 2018 Q2: Already in CSV.
# ⏭️ Skipping ORCL 2018 Q3: Already in CSV.
# ⏭️ Skipping ORCL 2018 Q4: Already in CSV.
# ⏭️ Skipping ORCL 2017 Q1: Already in CSV.
# ⏭️ Skipping ORCL 2017 Q2: Already in CSV.
# ⏭️ Skipping ORCL 2017 Q3: Already in CSV.
# ⏭️ Skipping ORCL 2017 Q4: Already in CSV.
# ⏭️ Skipping ORCL 2016 Q1: Already in CSV.
# ⏭️ Skipping ORCL 2016 Q2: Already in CSV.
# ⏭️ Skipping ORCL 2016 Q3: Already in CSV.
# ⏭️ Skipping ORCL 2016 Q4: Already in CSV.
# ⏭️ Skipping ORCL 2015 Q1: Already in CSV.
# ⏭️ Skipping ORCL 2015 Q2: Already in CSV.
# ⏭️ Skipping ORCL 2015 Q3: Already in CSV.
# ⏭️ Skipping ORCL 2015 Q4: Already in CSV.
# ⏭️ Skipping CSCO 2024 Q1: Already in CSV.
# ⏭️ Skipping CSCO 2024 Q2: Already in CSV.
# ⏭️ Skipping CSCO 2024 Q3: Already in CSV.
# ⏭️ Skipping CSCO 2024 Q4: Already in CSV.
# ⏭️ Skipping CSCO 2023 Q1: Already in CSV.
# ⏭️ Skipping CSCO 2023 Q2: Already in CSV.
# ⏭️ Skipping CSCO 2023 Q3: Already in CSV.
# ⏭️ Skipping CSCO 2023 Q4: Already in CSV.
# ⏭️ Skipping CSCO 2022 Q1: Already in CSV.
# ⏭️ Skipping CSCO 2022 Q2: Already in CSV.
# ✅ Successfully fetched data for CSCO in 2022 Q3
# ✅ Successfully fetched data for CSCO in 2022 Q4
# ✅ Successfully fetched data for CSCO in 2021 Q1
# ✅ Successfully fetched data for CSCO in 2021 Q2
# ✅ Successfully fetched data for CSCO in 2021 Q3
# ✅ Successfully fetched data for CSCO in 2021 Q4
# ✅ Successfully fetched data for CSCO in 2020 Q1
# ✅ Successfully fetched data for CSCO in 2020 Q2
# ✅ Successfully fetched data for CSCO in 2020 Q3
# ✅ Successfully fetched data for CSCO in 2020 Q4
# ✅ Successfully fetched data for CSCO in 2019 Q1
# ✅ Successfully fetched data for CSCO in 2019 Q2
# ✅ Successfully fetched data for CSCO in 2019 Q3
# ✅ Successfully fetched data for CSCO in 2019 Q4
# ✅ Successfully fetched data for CSCO in 2018 Q1
# ✅ Successfully fetched data for CSCO in 2018 Q2
# ✅ Successfully fetched data for CSCO in 2018 Q3
# ✅ Successfully fetched data for CSCO in 2018 Q4
# ✅ Successfully fetched data for CSCO in 2017 Q1
# ✅ Successfully fetched data for CSCO in 2017 Q2
# ✅ Successfully fetched data for CSCO in 2017 Q3
# ✅ Successfully fetched data for CSCO in 2017 Q4
# ✅ Successfully fetched data for CSCO in 2016 Q1
# ✅ Successfully fetched data for CSCO in 2016 Q2
# ✅ Successfully fetched data for CSCO in 2016 Q3
# ✅ Successfully fetched data for CSCO in 2016 Q4
# ✅ Successfully fetched data for CSCO in 2015 Q1
# ✅ Successfully fetched data for CSCO in 2015 Q2
# ✅ Successfully fetched data for CSCO in 2015 Q3
# ✅ Successfully fetched data for CSCO in 2015 Q4
# ✅ Successfully fetched data for NOW in 2024 Q1
# ✅ Successfully fetched data for NOW in 2024 Q2
# ✅ Successfully fetched data for NOW in 2024 Q3
# ❌ Error fetching data for NOW. Skipping to next ticker. Error: RetryError[<Future at 0x1338e2bd0 state=finished raised IndexError>]
# ✅ Successfully fetched data for ACN in 2024 Q1
# ✅ Successfully fetched data for ACN in 2024 Q2
# ✅ Successfully fetched data for ACN in 2024 Q3
# ✅ Successfully fetched data for ACN in 2024 Q4
# ✅ Successfully fetched data for ACN in 2023 Q1
# ✅ Successfully fetched data for ACN in 2023 Q2
# ✅ Successfully fetched data for ACN in 2023 Q3
# ✅ Successfully fetched data for ACN in 2023 Q4
# ✅ Successfully fetched data for ACN in 2022 Q1
# ✅ Successfully fetched data for ACN in 2022 Q2
# ✅ Successfully fetched data for ACN in 2022 Q3
# ✅ Successfully fetched data for ACN in 2022 Q4
# ✅ Successfully fetched data for ACN in 2021 Q1
# ✅ Successfully fetched data for ACN in 2021 Q2
# ✅ Successfully fetched data for ACN in 2021 Q3
# ✅ Successfully fetched data for ACN in 2021 Q4
# ✅ Successfully fetched data for ACN in 2020 Q1
# ✅ Successfully fetched data for ACN in 2020 Q2
# ✅ Successfully fetched data for ACN in 2020 Q3
# ✅ Successfully fetched data for ACN in 2020 Q4
# ✅ Successfully fetched data for ACN in 2019 Q1
# ✅ Successfully fetched data for ACN in 2019 Q2
# ✅ Successfully fetched data for ACN in 2019 Q3
# ✅ Successfully fetched data for ACN in 2019 Q4
# ✅ Successfully fetched data for ACN in 2018 Q1
# ✅ Successfully fetched data for ACN in 2018 Q2
# ✅ Successfully fetched data for ACN in 2018 Q3
# ✅ Successfully fetched data for ACN in 2018 Q4
# ✅ Successfully fetched data for ACN in 2017 Q1
# ✅ Successfully fetched data for ACN in 2017 Q2
# ✅ Successfully fetched data for ACN in 2017 Q3
# ✅ Successfully fetched data for ACN in 2017 Q4
# ✅ Successfully fetched data for ACN in 2016 Q1
# ✅ Successfully fetched data for ACN in 2016 Q2
# ✅ Successfully fetched data for ACN in 2016 Q3
# ✅ Successfully fetched data for ACN in 2016 Q4
# ✅ Successfully fetched data for ACN in 2015 Q1
# ✅ Successfully fetched data for ACN in 2015 Q2
# ✅ Successfully fetched data for ACN in 2015 Q3
# ✅ Successfully fetched data for ACN in 2015 Q4
# ✅ Successfully fetched data for IBM in 2024 Q1
# ✅ Successfully fetched data for IBM in 2024 Q2
# ✅ Successfully fetched data for IBM in 2024 Q3
# ❌ Error fetching data for IBM. Skipping to next ticker. Error: RetryError[<Future at 0x12fc7f0d0 state=finished raised IndexError>]
# ✅ Successfully fetched data for AMD in 2024 Q1
# ✅ Successfully fetched data for AMD in 2024 Q2
# ✅ Successfully fetched data for AMD in 2024 Q3
# ❌ Error fetching data for AMD. Skipping to next ticker. Error: RetryError[<Future at 0x1330d5010 state=finished raised IndexError>]
# ✅ Successfully fetched data for ADBE in 2024 Q1
# ✅ Successfully fetched data for ADBE in 2024 Q2
# ✅ Successfully fetched data for ADBE in 2024 Q3
# ✅ Successfully fetched data for ADBE in 2024 Q4
# ✅ Successfully fetched data for ADBE in 2023 Q1
# ✅ Successfully fetched data for ADBE in 2023 Q2
# ✅ Successfully fetched data for ADBE in 2023 Q3
# ✅ Successfully fetched data for ADBE in 2023 Q4
# ✅ Successfully fetched data for ADBE in 2022 Q1
# ✅ Successfully fetched data for ADBE in 2022 Q2
# ✅ Successfully fetched data for ADBE in 2022 Q3
# ✅ Successfully fetched data for ADBE in 2022 Q4
# ✅ Successfully fetched data for ADBE in 2021 Q1
# ✅ Successfully fetched data for ADBE in 2021 Q2
# ✅ Successfully fetched data for ADBE in 2021 Q3
# ✅ Successfully fetched data for ADBE in 2021 Q4
# ✅ Successfully fetched data for ADBE in 2020 Q1
# ✅ Successfully fetched data for ADBE in 2020 Q2
# ✅ Successfully fetched data for ADBE in 2020 Q3
# ✅ Successfully fetched data for ADBE in 2020 Q4
# ✅ Successfully fetched data for ADBE in 2019 Q1
# ✅ Successfully fetched data for ADBE in 2019 Q2
# ✅ Successfully fetched data for ADBE in 2019 Q3
# ✅ Successfully fetched data for ADBE in 2019 Q4
# ✅ Successfully fetched data for ADBE in 2018 Q1
# ✅ Successfully fetched data for ADBE in 2018 Q2
# ✅ Successfully fetched data for ADBE in 2018 Q3
# ✅ Successfully fetched data for ADBE in 2018 Q4
# ✅ Successfully fetched data for ADBE in 2017 Q1
# ✅ Successfully fetched data for ADBE in 2017 Q2
# ✅ Successfully fetched data for ADBE in 2017 Q3
# ✅ Successfully fetched data for ADBE in 2017 Q4
# ✅ Successfully fetched data for ADBE in 2016 Q1
# ✅ Successfully fetched data for ADBE in 2016 Q2
# ✅ Successfully fetched data for ADBE in 2016 Q3
# ✅ Successfully fetched data for ADBE in 2016 Q4
# ✅ Successfully fetched data for ADBE in 2015 Q1
# ✅ Successfully fetched data for ADBE in 2015 Q2
# ✅ Successfully fetched data for ADBE in 2015 Q3
# ✅ Successfully fetched data for ADBE in 2015 Q4
# ✅ Successfully fetched data for QCOM in 2024 Q1
# ✅ Successfully fetched data for QCOM in 2024 Q2
# ✅ Successfully fetched data for QCOM in 2024 Q3
# ✅ Successfully fetched data for QCOM in 2024 Q4
# ✅ Successfully fetched data for QCOM in 2023 Q1
# ✅ Successfully fetched data for QCOM in 2023 Q2
# ✅ Successfully fetched data for QCOM in 2023 Q3
# ✅ Successfully fetched data for QCOM in 2023 Q4
# ✅ Successfully fetched data for QCOM in 2022 Q1
# ✅ Successfully fetched data for QCOM in 2022 Q2
# ✅ Successfully fetched data for QCOM in 2022 Q3
# ✅ Successfully fetched data for QCOM in 2022 Q4
# ✅ Successfully fetched data for QCOM in 2021 Q1
# ✅ Successfully fetched data for QCOM in 2021 Q2
# ✅ Successfully fetched data for QCOM in 2021 Q3
# ✅ Successfully fetched data for QCOM in 2021 Q4
# ✅ Successfully fetched data for QCOM in 2020 Q1
# ✅ Successfully fetched data for QCOM in 2020 Q2
# ✅ Successfully fetched data for QCOM in 2020 Q3
# ✅ Successfully fetched data for QCOM in 2020 Q4
# ✅ Successfully fetched data for QCOM in 2019 Q1
# ✅ Successfully fetched data for QCOM in 2019 Q2
# ✅ Successfully fetched data for QCOM in 2019 Q3
# ✅ Successfully fetched data for QCOM in 2019 Q4
# ✅ Successfully fetched data for QCOM in 2018 Q1
# ✅ Successfully fetched data for QCOM in 2018 Q2
# ✅ Successfully fetched data for QCOM in 2018 Q3
# ✅ Successfully fetched data for QCOM in 2018 Q4
# ✅ Successfully fetched data for QCOM in 2017 Q1
# ✅ Successfully fetched data for QCOM in 2017 Q2
# ✅ Successfully fetched data for QCOM in 2017 Q3
# ✅ Successfully fetched data for QCOM in 2017 Q4
# ✅ Successfully fetched data for QCOM in 2016 Q1
# ✅ Successfully fetched data for QCOM in 2016 Q2
# ✅ Successfully fetched data for QCOM in 2016 Q3
# ✅ Successfully fetched data for QCOM in 2016 Q4
# ✅ Successfully fetched data for QCOM in 2015 Q1
# ✅ Successfully fetched data for QCOM in 2015 Q2
# ✅ Successfully fetched data for QCOM in 2015 Q3
# ✅ Successfully fetched data for QCOM in 2015 Q4
# ✅ Successfully fetched data for TXN in 2024 Q1
# ✅ Successfully fetched data for TXN in 2024 Q2
# ✅ Successfully fetched data for TXN in 2024 Q3
# ✅ Successfully fetched data for TXN in 2024 Q4
# ✅ Successfully fetched data for TXN in 2023 Q1
# ✅ Successfully fetched data for TXN in 2023 Q2
# ✅ Successfully fetched data for TXN in 2023 Q3
# ✅ Successfully fetched data for TXN in 2023 Q4
# ✅ Successfully fetched data for TXN in 2022 Q1
# ✅ Successfully fetched data for TXN in 2022 Q2
# ✅ Successfully fetched data for TXN in 2022 Q3
# ✅ Successfully fetched data for TXN in 2022 Q4
# ✅ Successfully fetched data for TXN in 2021 Q1
# ✅ Successfully fetched data for TXN in 2021 Q2
# ✅ Successfully fetched data for TXN in 2021 Q3
# ✅ Successfully fetched data for TXN in 2021 Q4
# ✅ Successfully fetched data for TXN in 2020 Q1
# ✅ Successfully fetched data for TXN in 2020 Q2
# ✅ Successfully fetched data for TXN in 2020 Q3
# ✅ Successfully fetched data for TXN in 2020 Q4
# ✅ Successfully fetched data for TXN in 2019 Q1
# ✅ Successfully fetched data for TXN in 2019 Q2
# ✅ Successfully fetched data for TXN in 2019 Q3
# ✅ Successfully fetched data for TXN in 2019 Q4
# ✅ Successfully fetched data for TXN in 2018 Q1
# ✅ Successfully fetched data for TXN in 2018 Q2
# ✅ Successfully fetched data for TXN in 2018 Q3
# ✅ Successfully fetched data for TXN in 2018 Q4
# ✅ Successfully fetched data for TXN in 2017 Q1
# ✅ Successfully fetched data for TXN in 2017 Q2
# ✅ Successfully fetched data for TXN in 2017 Q3
# ✅ Successfully fetched data for TXN in 2017 Q4
# ✅ Successfully fetched data for TXN in 2016 Q1
# ✅ Successfully fetched data for TXN in 2016 Q2
# ✅ Successfully fetched data for TXN in 2016 Q3
# ✅ Successfully fetched data for TXN in 2016 Q4
# ✅ Successfully fetched data for TXN in 2015 Q1
# ✅ Successfully fetched data for TXN in 2015 Q2
# ✅ Successfully fetched data for TXN in 2015 Q3
# ✅ Successfully fetched data for TXN in 2015 Q4
# ✅ Successfully fetched data for INTU in 2024 Q1
# ✅ Successfully fetched data for INTU in 2024 Q2
# ✅ Successfully fetched data for INTU in 2024 Q3
# ✅ Successfully fetched data for INTU in 2024 Q4
# ✅ Successfully fetched data for INTU in 2023 Q1
# ✅ Successfully fetched data for INTU in 2023 Q2
# ✅ Successfully fetched data for INTU in 2023 Q3
# ✅ Successfully fetched data for INTU in 2023 Q4
# ✅ Successfully fetched data for INTU in 2022 Q1
# ✅ Successfully fetched data for INTU in 2022 Q2
# ✅ Successfully fetched data for INTU in 2022 Q3
# ✅ Successfully fetched data for INTU in 2022 Q4
# ✅ Successfully fetched data for INTU in 2021 Q1
# ✅ Successfully fetched data for INTU in 2021 Q2
# ✅ Successfully fetched data for INTU in 2021 Q3
# ✅ Successfully fetched data for INTU in 2021 Q4
# ✅ Successfully fetched data for INTU in 2020 Q1
# ✅ Successfully fetched data for INTU in 2020 Q2
# ✅ Successfully fetched data for INTU in 2020 Q3
# ✅ Successfully fetched data for INTU in 2020 Q4
# ✅ Successfully fetched data for INTU in 2019 Q1
# ✅ Successfully fetched data for INTU in 2019 Q2
# ✅ Successfully fetched data for INTU in 2019 Q3
# ✅ Successfully fetched data for INTU in 2019 Q4
# ✅ Successfully fetched data for INTU in 2018 Q1
# ✅ Successfully fetched data for INTU in 2018 Q2
# ✅ Successfully fetched data for INTU in 2018 Q3
# ✅ Successfully fetched data for INTU in 2018 Q4
# ✅ Successfully fetched data for INTU in 2017 Q1
# ✅ Successfully fetched data for INTU in 2017 Q2
# ✅ Successfully fetched data for INTU in 2017 Q3
# ✅ Successfully fetched data for INTU in 2017 Q4
# ✅ Successfully fetched data for INTU in 2016 Q1
# ✅ Successfully fetched data for INTU in 2016 Q2
# ✅ Successfully fetched data for INTU in 2016 Q3
# ✅ Successfully fetched data for INTU in 2016 Q4
# ✅ Successfully fetched data for INTU in 2015 Q1
# ✅ Successfully fetched data for INTU in 2015 Q2
# ✅ Successfully fetched data for INTU in 2015 Q3
# ✅ Successfully fetched data for INTU in 2015 Q4
# ✅ Successfully fetched data for AMAT in 2024 Q1
# ✅ Successfully fetched data for AMAT in 2024 Q2
# ✅ Successfully fetched data for AMAT in 2024 Q3
# ✅ Successfully fetched data for AMAT in 2024 Q4
# ✅ Successfully fetched data for AMAT in 2023 Q1
# ✅ Successfully fetched data for AMAT in 2023 Q2
# ✅ Successfully fetched data for AMAT in 2023 Q3
# ✅ Successfully fetched data for AMAT in 2023 Q4
# ✅ Successfully fetched data for AMAT in 2022 Q1
# ✅ Successfully fetched data for AMAT in 2022 Q2
# ✅ Successfully fetched data for AMAT in 2022 Q3
# ✅ Successfully fetched data for AMAT in 2022 Q4
# ✅ Successfully fetched data for AMAT in 2021 Q1
# ✅ Successfully fetched data for AMAT in 2021 Q2
# ✅ Successfully fetched data for AMAT in 2021 Q3
# ✅ Successfully fetched data for AMAT in 2021 Q4
# ✅ Successfully fetched data for AMAT in 2020 Q1
# ✅ Successfully fetched data for AMAT in 2020 Q2
# ✅ Successfully fetched data for AMAT in 2020 Q3
# ✅ Successfully fetched data for AMAT in 2020 Q4
# ✅ Successfully fetched data for AMAT in 2019 Q1
# ✅ Successfully fetched data for AMAT in 2019 Q2
# ✅ Successfully fetched data for AMAT in 2019 Q3
# ✅ Successfully fetched data for AMAT in 2019 Q4
# ✅ Successfully fetched data for AMAT in 2018 Q1
# ✅ Successfully fetched data for AMAT in 2018 Q2
# ✅ Successfully fetched data for AMAT in 2018 Q3
# ✅ Successfully fetched data for AMAT in 2018 Q4
# ✅ Successfully fetched data for AMAT in 2017 Q1
# ✅ Successfully fetched data for AMAT in 2017 Q2
# ✅ Successfully fetched data for AMAT in 2017 Q3
# ✅ Successfully fetched data for AMAT in 2017 Q4
# ✅ Successfully fetched data for AMAT in 2016 Q1
# ✅ Successfully fetched data for AMAT in 2016 Q2
# ✅ Successfully fetched data for AMAT in 2016 Q3
# ✅ Successfully fetched data for AMAT in 2016 Q4
# ✅ Successfully fetched data for AMAT in 2015 Q1
# ✅ Successfully fetched data for AMAT in 2015 Q2
# ✅ Successfully fetched data for AMAT in 2015 Q3
# ✅ Successfully fetched data for AMAT in 2015 Q4
# ✅ Successfully fetched data for PLTR in 2024 Q1
# ✅ Successfully fetched data for PLTR in 2024 Q2
# ✅ Successfully fetched data for PLTR in 2024 Q3
# ❌ Error fetching data for PLTR. Skipping to next ticker. Error: RetryError[<Future at 0x13318a550 state=finished raised IndexError>]
# ✅ Successfully fetched data for UBER in 2024 Q1
# ✅ Successfully fetched data for UBER in 2024 Q2
# ✅ Successfully fetched data for UBER in 2024 Q3
# ❌ Error fetching data for UBER. Skipping to next ticker. Error: RetryError[<Future at 0x133887b10 state=finished raised IndexError>]
# ✅ Successfully fetched data for ANET in 2024 Q1
# ✅ Successfully fetched data for ANET in 2024 Q2
# ✅ Successfully fetched data for ANET in 2024 Q3
# ❌ Error fetching data for ANET. Skipping to next ticker. Error: RetryError[<Future at 0x1323b2450 state=finished raised IndexError>]
# ✅ Successfully fetched data for PANW in 2024 Q1
# ✅ Successfully fetched data for PANW in 2024 Q2
# ✅ Successfully fetched data for PANW in 2024 Q3
# ✅ Successfully fetched data for PANW in 2024 Q4
# ✅ Successfully fetched data for PANW in 2023 Q1
# ✅ Successfully fetched data for PANW in 2023 Q2
# ✅ Successfully fetched data for PANW in 2023 Q3
# ✅ Successfully fetched data for PANW in 2023 Q4
# ✅ Successfully fetched data for PANW in 2022 Q1
# ✅ Successfully fetched data for PANW in 2022 Q2
# ✅ Successfully fetched data for PANW in 2022 Q3
# ✅ Successfully fetched data for PANW in 2022 Q4
# ✅ Successfully fetched data for PANW in 2021 Q1
# ✅ Successfully fetched data for PANW in 2021 Q2
# ✅ Successfully fetched data for PANW in 2021 Q3
# ✅ Successfully fetched data for PANW in 2021 Q4
# ✅ Successfully fetched data for PANW in 2020 Q1
# ✅ Successfully fetched data for PANW in 2020 Q2
# ✅ Successfully fetched data for PANW in 2020 Q3
# ✅ Successfully fetched data for PANW in 2020 Q4
# ✅ Successfully fetched data for PANW in 2019 Q1
# ✅ Successfully fetched data for PANW in 2019 Q2
# ✅ Successfully fetched data for PANW in 2019 Q3
# ✅ Successfully fetched data for PANW in 2019 Q4
# ✅ Successfully fetched data for PANW in 2018 Q1
# ✅ Successfully fetched data for PANW in 2018 Q2
# ✅ Successfully fetched data for PANW in 2018 Q3
# ✅ Successfully fetched data for PANW in 2018 Q4
# ✅ Successfully fetched data for PANW in 2017 Q1
# ✅ Successfully fetched data for PANW in 2017 Q2
# ✅ Successfully fetched data for PANW in 2017 Q3
# ✅ Successfully fetched data for PANW in 2017 Q4
# ✅ Successfully fetched data for PANW in 2016 Q1
# ✅ Successfully fetched data for PANW in 2016 Q2
# ✅ Successfully fetched data for PANW in 2016 Q3
# ✅ Successfully fetched data for PANW in 2016 Q4
# ✅ Successfully fetched data for PANW in 2015 Q1
# ✅ Successfully fetched data for PANW in 2015 Q2
# ✅ Successfully fetched data for PANW in 2015 Q3
# ✅ Successfully fetched data for PANW in 2015 Q4
# ✅ Successfully fetched data for MU in 2024 Q1
# ✅ Successfully fetched data for MU in 2024 Q2
# ✅ Successfully fetched data for MU in 2024 Q3
# ✅ Successfully fetched data for MU in 2024 Q4
# ✅ Successfully fetched data for MU in 2023 Q1
# ✅ Successfully fetched data for MU in 2023 Q2
# ✅ Successfully fetched data for MU in 2023 Q3
# ✅ Successfully fetched data for MU in 2023 Q4
# ✅ Successfully fetched data for MU in 2022 Q1
# ✅ Successfully fetched data for MU in 2022 Q2
# ✅ Successfully fetched data for MU in 2022 Q3
# ✅ Successfully fetched data for MU in 2022 Q4
# ✅ Successfully fetched data for MU in 2021 Q1
# ✅ Successfully fetched data for MU in 2021 Q2
# ✅ Successfully fetched data for MU in 2021 Q3
# ✅ Successfully fetched data for MU in 2021 Q4
# ✅ Successfully fetched data for MU in 2020 Q1
# ✅ Successfully fetched data for MU in 2020 Q2
# ✅ Successfully fetched data for MU in 2020 Q3
# ✅ Successfully fetched data for MU in 2020 Q4
# ✅ Successfully fetched data for MU in 2019 Q1
# ✅ Successfully fetched data for MU in 2019 Q2
# ✅ Successfully fetched data for MU in 2019 Q3
# ✅ Successfully fetched data for MU in 2019 Q4
# ✅ Successfully fetched data for MU in 2018 Q1
# ✅ Successfully fetched data for MU in 2018 Q2
# ✅ Successfully fetched data for MU in 2018 Q3
# ✅ Successfully fetched data for MU in 2018 Q4
# ✅ Successfully fetched data for MU in 2017 Q1
# ✅ Successfully fetched data for MU in 2017 Q2
# ✅ Successfully fetched data for MU in 2017 Q3
# ✅ Successfully fetched data for MU in 2017 Q4
# ✅ Successfully fetched data for MU in 2016 Q1
# ✅ Successfully fetched data for MU in 2016 Q2
# ✅ Successfully fetched data for MU in 2016 Q3
# ✅ Successfully fetched data for MU in 2016 Q4
# ✅ Successfully fetched data for MU in 2015 Q1
# ✅ Successfully fetched data for MU in 2015 Q2
# ✅ Successfully fetched data for MU in 2015 Q3
# ✅ Successfully fetched data for MU in 2015 Q4
# ✅ Successfully fetched data for ADP in 2024 Q1
# ✅ Successfully fetched data for ADP in 2024 Q2
# ✅ Successfully fetched data for ADP in 2024 Q3
# ✅ Successfully fetched data for ADP in 2024 Q4
# ✅ Successfully fetched data for ADP in 2023 Q1
# ✅ Successfully fetched data for ADP in 2023 Q2
# ✅ Successfully fetched data for ADP in 2023 Q3
# ✅ Successfully fetched data for ADP in 2023 Q4
# ✅ Successfully fetched data for ADP in 2022 Q1
# ✅ Successfully fetched data for ADP in 2022 Q2
# ✅ Successfully fetched data for ADP in 2022 Q3
# ✅ Successfully fetched data for ADP in 2022 Q4
# ✅ Successfully fetched data for ADP in 2021 Q1
# ✅ Successfully fetched data for ADP in 2021 Q2
# ✅ Successfully fetched data for ADP in 2021 Q3
# ✅ Successfully fetched data for ADP in 2021 Q4
# ✅ Successfully fetched data for ADP in 2020 Q1
# ✅ Successfully fetched data for ADP in 2020 Q2
# ✅ Successfully fetched data for ADP in 2020 Q3
# ✅ Successfully fetched data for ADP in 2020 Q4
# ✅ Successfully fetched data for ADP in 2019 Q1
# ✅ Successfully fetched data for ADP in 2019 Q2
# ✅ Successfully fetched data for ADP in 2019 Q3
# ✅ Successfully fetched data for ADP in 2019 Q4
# ✅ Successfully fetched data for ADP in 2018 Q1
# ✅ Successfully fetched data for ADP in 2018 Q2
# ✅ Successfully fetched data for ADP in 2018 Q3
# ✅ Successfully fetched data for ADP in 2018 Q4
# ✅ Successfully fetched data for ADP in 2017 Q1
# ✅ Successfully fetched data for ADP in 2017 Q2
# ✅ Successfully fetched data for ADP in 2017 Q3
# ✅ Successfully fetched data for ADP in 2017 Q4
# ✅ Successfully fetched data for ADP in 2016 Q1
# ✅ Successfully fetched data for ADP in 2016 Q2
# ✅ Successfully fetched data for ADP in 2016 Q3
# ✅ Successfully fetched data for ADP in 2016 Q4
# ✅ Successfully fetched data for ADP in 2015 Q1
# ✅ Successfully fetched data for ADP in 2015 Q2
# ✅ Successfully fetched data for ADP in 2015 Q3
# ✅ Successfully fetched data for ADP in 2015 Q4
# ✅ Successfully fetched data for FI in 2024 Q1
# ✅ Successfully fetched data for FI in 2024 Q2
# ✅ Successfully fetched data for FI in 2024 Q3
# ❌ Error fetching data for FI. Skipping to next ticker. Error: RetryError[<Future at 0x1330fded0 state=finished raised IndexError>]
# ✅ Successfully fetched data for ADI in 2024 Q1
# ✅ Successfully fetched data for ADI in 2024 Q2
# ✅ Successfully fetched data for ADI in 2024 Q3
# ✅ Successfully fetched data for ADI in 2024 Q4
# ✅ Successfully fetched data for ADI in 2023 Q1
# ✅ Successfully fetched data for ADI in 2023 Q2
# ✅ Successfully fetched data for ADI in 2023 Q3
# ✅ Successfully fetched data for ADI in 2023 Q4
# ✅ Successfully fetched data for ADI in 2022 Q1
# ✅ Successfully fetched data for ADI in 2022 Q2
# ✅ Successfully fetched data for ADI in 2022 Q3
# ✅ Successfully fetched data for ADI in 2022 Q4
# ✅ Successfully fetched data for ADI in 2021 Q1
# ✅ Successfully fetched data for ADI in 2021 Q2
# ✅ Successfully fetched data for ADI in 2021 Q3
# ✅ Successfully fetched data for ADI in 2021 Q4
# ✅ Successfully fetched data for ADI in 2020 Q1
# ✅ Successfully fetched data for ADI in 2020 Q2
# ✅ Successfully fetched data for ADI in 2020 Q3
# ✅ Successfully fetched data for ADI in 2020 Q4
# ✅ Successfully fetched data for ADI in 2019 Q1
# ✅ Successfully fetched data for ADI in 2019 Q2
# ✅ Successfully fetched data for ADI in 2019 Q3
# ✅ Successfully fetched data for ADI in 2019 Q4
# ✅ Successfully fetched data for ADI in 2018 Q1
# ✅ Successfully fetched data for ADI in 2018 Q2
# ✅ Successfully fetched data for ADI in 2018 Q3
# ✅ Successfully fetched data for ADI in 2018 Q4
# ✅ Successfully fetched data for ADI in 2017 Q1
# ✅ Successfully fetched data for ADI in 2017 Q2
# ✅ Successfully fetched data for ADI in 2017 Q3
# ✅ Successfully fetched data for ADI in 2017 Q4
# ✅ Successfully fetched data for ADI in 2016 Q1
# ✅ Successfully fetched data for ADI in 2016 Q2
# ✅ Successfully fetched data for ADI in 2016 Q3
# ✅ Successfully fetched data for ADI in 2016 Q4
# ✅ Successfully fetched data for ADI in 2015 Q1
# ✅ Successfully fetched data for ADI in 2015 Q2
# ✅ Successfully fetched data for ADI in 2015 Q3
# ✅ Successfully fetched data for ADI in 2015 Q4
# ✅ Successfully fetched data for LRCX in 2024 Q1
# ✅ Successfully fetched data for LRCX in 2024 Q2
# ✅ Successfully fetched data for LRCX in 2024 Q3
# ✅ Successfully fetched data for LRCX in 2024 Q4
# ✅ Successfully fetched data for LRCX in 2023 Q1
# ✅ Successfully fetched data for LRCX in 2023 Q2
# ✅ Successfully fetched data for LRCX in 2023 Q3
# ✅ Successfully fetched data for LRCX in 2023 Q4
# ✅ Successfully fetched data for LRCX in 2022 Q1
# ✅ Successfully fetched data for LRCX in 2022 Q2
# ✅ Successfully fetched data for LRCX in 2022 Q3
# ✅ Successfully fetched data for LRCX in 2022 Q4
# ✅ Successfully fetched data for LRCX in 2021 Q1
# ✅ Successfully fetched data for LRCX in 2021 Q2
# ✅ Successfully fetched data for LRCX in 2021 Q3
# ✅ Successfully fetched data for LRCX in 2021 Q4
# ✅ Successfully fetched data for LRCX in 2020 Q1
# ✅ Successfully fetched data for LRCX in 2020 Q2
# ✅ Successfully fetched data for LRCX in 2020 Q3
# ❌ Error fetching data for LRCX. Skipping to next ticker. Error: RetryError[<Future at 0x12fc7f0d0 state=finished raised JSONDecodeError>]
# ❌ Error fetching data for KLAC. Skipping to next ticker. Error: RetryError[<Future at 0x133890fd0 state=finished raised JSONDecodeError>]
# ❌ Error fetching data for INTC. Skipping to next ticker. Error: RetryError[<Future at 0x133946a50 state=finished raised JSONDecodeError>]
# ❌ Error fetching data for APH. Skipping to next ticker. Error: RetryError[<Future at 0x13375c4d0 state=finished raised JSONDecodeError>]
# ❌ Error fetching data for CDNS. Skipping to next ticker. Error: RetryError[<Future at 0x1330e94d0 state=finished raised JSONDecodeError>]
# ❌ Error fetching data for CRWD. Skipping to next ticker. Error: RetryError[<Future at 0x1323b27d0 state=finished raised JSONDecodeError>]
# ❌ Error fetching data for SNPS. Skipping to next ticker. Error: RetryError[<Future at 0x1338d52d0 state=finished raised JSONDecodeError>]
# ❌ Error fetching data for MSI. Skipping to next ticker. Error: RetryError[<Future at 0x133918490 state=finished raised JSONDecodeError>]
# ❌ Error fetching data for ADSK. Skipping to next ticker. Error: RetryError[<Future at 0x133885cd0 state=finished raised JSONDecodeError>]
# ❌ Error fetching data for FTNT. Skipping to next ticker. Error: RetryError[<Future at 0x1331ce190 state=finished raised JSONDecodeError>]
# ❌ Error fetching data for ROP. Skipping to next ticker. Error: RetryError[<Future at 0x13318b390 state=finished raised JSONDecodeError>]
# ❌ Error fetching data for NXPI. Skipping to next ticker. Error: RetryError[<Future at 0x1337d3ed0 state=finished raised JSONDecodeError>]
# ❌ Error fetching data for WDAY. Skipping to next ticker. Error: RetryError[<Future at 0x1338d77d0 state=finished raised JSONDecodeError>]
# ❌ Error fetching data for TEL. Skipping to next ticker. Error: RetryError[<Future at 0x133884850 state=finished raised JSONDecodeError>]
# ❌ Error fetching data for PAYX. Skipping to next ticker. Error: RetryError[<Future at 0x1322504d0 state=finished raised JSONDecodeError>]
# ❌ Error fetching data for FICO. Skipping to next ticker. Error: RetryError[<Future at 0x1330bec50 state=finished raised JSONDecodeError>]
# ❌ Error fetching data for FIS. Skipping to next ticker. Error: RetryError[<Future at 0x13373f310 state=finished raised JSONDecodeError>]
# ❌ Error fetching data for GLW. Skipping to next ticker. Error: RetryError[<Future at 0x13391ae90 state=finished raised JSONDecodeError>]
# ❌ Error fetching data for IT. Skipping to next ticker. Error: RetryError[<Future at 0x133890b50 state=finished raised JSONDecodeError>]
# ❌ Error fetching data for CTSH. Skipping to next ticker. Error: RetryError[<Future at 0x13320c790 state=finished raised JSONDecodeError>]
# ❌ Error fetching data for DELL. Skipping to next ticker. Error: RetryError[<Future at 0x1337e3950 state=finished raised JSONDecodeError>]
# ⚠️ Skipping MPWR: Not found in DCF API.
# ⚠️ Skipping GRMN: Not found in DCF API.
# ⚠️ Skipping HPQ: Not found in DCF API.
# ⚠️ Skipping HPE: Not found in DCF API.
# ⚠️ Skipping MCHP: Not found in DCF API.
#
# ✅ Data saved to earnings_call_transcripts.csv
